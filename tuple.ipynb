# %%
t1=(1,2,3,4,5)
print(t1)
# Out:
# (1, 2, 3, 4, 5)

# %%
print (type(t1))
# Out:
# <class 'tuple'>

# %%
print(len(t1))
# Out:
# 5

# %%
t2=("a","b","c","d","e")
print(t2)
# Out:
# ('a', 'b', 'c', 'd', 'e')

# %%
t2[3]
# Out:
# 'd'

# %%
t2[4]
# Out:
# 'e'

# %%
t2[0]
# Out:
# 'a'

# %%
t2[-1]
# Out:
# 'e'

# %%
t2[-2]
# Out:
# 'd'

# %%
t2[2:4]
# Out:
# ('c', 'd')

# %%
t2[-4:-1]
# Out:
# ('b', 'c', 'd')

# %%
t3=(1,)

# %%
print(t3)
# Out:
# (1,)

# %%
print(type(t3))
# Out:
# <class 'tuple'>

# %%
sports=("hockey","cricket","volley ball")
print(sports)
# Out:
# ('hockey', 'cricket', 'volley ball')
