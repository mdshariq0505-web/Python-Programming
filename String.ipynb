# %%
print('hello aaft')
# Out:
# hello aaft

# %%
a='hello,aaft'
print(a)
# Out:
# hello,aaft

# %%
b="""himanshu is naughty boy.
Yash is not saying anything.
Gungun is not practicing python"""
print(b)
# Out:
# himanshu is naughty boy.
# Yash is not saying anything.
# Gungun is not practicing python

# %%
#Access of element
b='hello,world'

# %%
#slicing
print(b[2:5])
# Out:
# llo

# %%
print(b[2:])
# Out:
# llo,world

# %%
print(b[:5])
# Out:
# hello

# %%
#negative indexing
c='hello,world'

# %%
print(b[-5:-2])
# Out:
# wor

# %%
s1='aaft aaft aaft sods'
x=s1.count('aaft')
print(x)
# Out:
# 3

# %%
s1='aaft aaft aaft sods'
y=s1.count('sods')
print(y)
# Out:
# 1

# %%
s1='aaft aaft aaft sods'
y=s1.find('sods')
print(y)
# Out:
# 15

# %%
a='hello world'
print(a.upper())
# Out:
# HELLO WORLD

# %%
A='Hello World'
print(A.lower())
# Out:
# hello world

# %%
#strip()method
a=' Hello World '
print(a.strip())
# Out:
# Hello World

# %%
a='hello'
b='world'
c=a+b
print(c)
# Out:
# helloworld

# %%
a='Hello'
b='world'
c=a + ' ' + b
print(c)
# Out:
# Hello world

# %%
#we cannot combine strings and numbers like this:
age=36
txt='my name is john,i am'+ age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_16307/3865804411.py in <cell line: 0>()
#       1 #we cannot combine strings and numbers like this:
#       2 age=36
# ----> 3 txt='my name is john,i am'+ age
#       4 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#we can combine strings and numbers by using the format () method
age = 36
txt = "My name is john and  I am {}"
print (txt.format(age))
# Out:
# My name is john and  I am 36

# %%
#the format method takes unlimited numbers of argument and are placed into the respective place
quantity=3
itemno=567
price=49.95
myorder="i want {} pieces of item {} for {} dollar"
print(myorder.format(quantity,itemno,price))
# Out:
# i want 3 pieces of item 567 for 49.95 dollar

# %%
txt="hello and \"welcome\" to  my world "
x=txt.capitalize()
print(x)
# Out:
# Hello and "welcome" to  my world

# %%
txt="hello and \"welcome\" to  my world "
x=txt.title()
print(x)
# Out:
# Hello And "Welcome" To  My World

# %%
txt="hello welcome to my world"
x=txt.find("e",5,10)
print(x)
# Out:
# 7

# %%
txt="hello welcome to my world"
x=txt.index("welcome")
print(x)
# Out:
# 6

# %%
#join all items in atuple into a string using a hash character as a separator
mytuple = ( "john","peter","vicky")
x="#".join(my Tuple)
print(x)
# Out:
#   File "/tmp/ipykernel_19196/2916796952.py", line 3
#     x="#".join(my Tuple)
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
txt=" I like banana"
x=txt.replace("banana","appples")
print(x)
# Out:
#  I like appples

# %%
txt=" i could eat bananas all day"
x = txt.partition("apples")
print(x)
# Out:
# (' i could eat bananas all day', '', '')

# %%
txt=" txt,hello, my name is peter , i am 26 year old"
x=txt.split(",")
print(x)
# Out:
# [' txt', 'hello', ' my name is peter ', ' i am 26 year old']
