# %%
LIST1=["a","b","c","d","a"]
print(LIST1)
# Out:
# ['a', 'b', 'c', 'd', 'a']

# %%
LIST1[1]
# Out:
# 'b'

# %%
LIST1[2]
# Out:
# 'c'

# %%
LIST1[0]
# Out:
# 'a'

# %%
LIST1[3]
# Out:
# 'd'

# %%
LIST1[4]
# Out:
# 'a'

# %%
#RANGE OF INDEX
LIST1[1:3]
# Out:
# ['b', 'c']

# %%
LIST1[1:4]
# Out:
# ['b', 'c', 'd']

# %%
LIST1[2:4]
# Out:
# ['c', 'd']

# %%
LIST1[3:4]
# Out:
# ['d']

# %%
LIST1[0:2]
# Out:
# ['a', 'b']

# %%
LIST1[1:]
# Out:
# ['b', 'c', 'd', 'a']

# %%
LIST1[0:]
# Out:
# ['a', 'b', 'c', 'd', 'a']

# %%
LIST1[0:5]
# Out:
# ['a', 'b', 'c', 'd', 'a']

# %%
#NEGATIVE INDEXING
LIST1[-3]
# Out:
# 'c'

# %%
LIST1[-4]
# Out:
# 'b'

# %%
#RANGE OF INDEX
LIST1[-5:-3]
# Out:
# ['a', 'b']

# %%
LIST1[-1]
# Out:
# 'a'

# %%
LIST1[-1:]
# Out:
# ['a']

# %%
LIST1[-5]
# Out:
# 'a'

# %%
LIST1[-5:]
# Out:
# ['a', 'b', 'c', 'd', 'a']

# %%
LIST1[:-2]
# Out:
# ['a', 'b', 'c']

# %%
DIPLOMA=["PARVEEN","SAKSHI","NAYANSHI","KAIF","DANISH","HEMANT","SANJEEV","SHARIQ"]
print(DIPLOMA)
# Out:
# ['PARVEEN', 'SAKSHI', 'NAYANSHI', 'KAIF', 'DANISH', 'HEMANT', 'SANJEEV', 'SHARIQ']

# %%
DIPLOMA[1]
# Out:
# 'SAKSHI'

# %%
DIPLOMA[0]
# Out:
# 'PARVEEN'

# %%
DIPLOMA[0:3]
# Out:
# ['PARVEEN', 'SAKSHI', 'NAYANSHI']

# %%
DIPLOMA[3:9]
# Out:
# ['KAIF', 'DANISH', 'HEMANT', 'SANJEEV', 'SHARIQ']

# %%
l2=[1,2,3,4,5,6,7]

# %%
l2
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
l2[2]=8

# %%
l2
# Out:
# [1, 2, 8, 4, 5, 6, 7]

# %%
#replace elements
l2[1:3]="a","b"

# %%
l2
# Out:
# [1, 'a', 'b', 4, 5, 6, 7]

# %%
course=["python","sql","stats"]
print(course)
# Out:
# ['python', 'sql', 'stats']

# %%
course.insert(3,'jawa')
course
# Out:
# ['Python', 'SQL', 'Stats', 'jawa']

# %%
company=['tcs','infoysys','wipro']
print(company)
# Out:
# ['tcs', 'infoysys', 'wipro']

# %%
course.extend(company)

# %%
print(course)
# Out:
# ['Python', 'SQL', 'Stats', 'jawa', 'algo', 'Excel', 'Excel', 'tcs', 'infoysys', 'wipro']

# %%
sport=['cricket','football','hockey']
print(sport)
# Out:
# ['cricket', 'football', 'hockey']

# %%
sport.append('badminton')

# %%
sport
# Out:
# ['cricket', 'football', 'hockey', 'badminton']

# %%
sport.insert(1,'table tennis')
sport
# Out:
# ['cricket', 'table tennis', 'football', 'hockey', 'badminton']

# %%
place=["delhi",'Noida']

# %%
place
# Out:
# ['delhi', 'Noida']
